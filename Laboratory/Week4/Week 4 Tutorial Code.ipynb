# %% [markdown]
# # Week 4 Tutorials

# %%
import pandas as pd

# %%
df = pd.read_fwf('data/Patients.txt', 
                 colspecs='infer', 
                 header=None)

# %%
df = pd.read_fwf('https://www.alexandriarepository.org/wp-content/uploads/20150629135742/Patients.txt',
                 colspecs='infer',
                 header=None)

# %%
df.shape
# Out:
# (30, 2)

# %%
df.head()
# Out:
#                          0   1
# 0  001M11/11/1998 88140 80  10
# 1  016F11/13/1998 84120 78  X0
# 2  033X10/21/1998 68190100  31
# 3  004F01/01/1999101200120  5A
# 4  XX5M05/07/1998 68120 80  10

# %% [markdown]
# ## Reading the File

# %%
df = pd.read_fwf('Patients.txt', 
                 widths=[3,1,10,3,3,3,3,1],
                 header=None
                )

# %%
# Practise 1
df.shape
# df.shape says that it has 30 rows and 8 columns.
# Out:
# (30, 8)

# %%
df.sample(3)
# Out:
#      ID Gender       Visit    HR    SBP   DBP   DX AE
# 27  028      F  03/28/1998  66.0  150.0  90.0    3  0
# 5   006    NaN  06/15/1999  72.0  102.0  68.0    6  1
# 13  014      M  02/02/1999  22.0  130.0  90.0  NaN  1

# %%
# Practise 2
df.columns = ['ID','Gender','Visit','HR','SBP','DBP','DX','AE']

# %%
df
# Out:
#      ID Gender       Visit     HR    SBP    DBP   DX AE
# 0   001      M  11/11/1998   88.0  140.0   80.0    1  0
# 1   016      F  11/13/1998   84.0  120.0   78.0    X  0
# 2   033      X  10/21/1998   68.0  190.0  100.0    3  1
# 3   004      F  01/01/1999  101.0  200.0  120.0    5  A
# 4   XX5      M  05/07/1998   68.0  120.0   80.0    1  0
# 5   006    NaN  06/15/1999   72.0  102.0   68.0    6  1
# 6   007      M  08/32/1998   88.0  148.0  102.0  NaN  0
# 7   008      F  08/08/1998  210.0    NaN    NaN    7  0
# 8   009      M  09/25/1999   86.0  240.0  180.0    4  1
# 9   010      F  10/19/1999   40.0  120.0    NaN    1  0
# 10  011      M  13/13/1998   68.0  300.0   20.0    4  1
# 11  012      M    10/12/98   60.0  122.0   74.0  NaN  0
# 12  013      2  08/23/1999   74.0  108.0   64.0  NaN  1
# 13  014      M  02/02/1999   22.0  130.0   90.0  NaN  1
# 14  002      f  11/13/1998   84.0  120.0   78.0    X  0
# 15  003      M  11/12/1999   58.0  112.0   74.0  NaN  0
# ...

# %% [markdown]
# ### Visualizing the Data

# %%
df['SBP'].head()
# Out:
# 0    140.0
# 1    120.0
# 2    190.0
# 3    200.0
# 4    120.0
# Name: SBP, dtype: float64

# %%
# Practise 3
# %matplotlib inline
import matplotlib.pyplot as plt
#plt.scatter(df['HR'], df['SBP'])
#plt.show()
plt.scatter(df['HR'],df['SBP'], c=df['DBP'], cmap='hot')
plt.xlabel('Diastolic Blood Pressure (DBP)')
plt.ylabel('Systolic Blood Pressure (SBP)')
# Out:
# Text(0, 0.5, 'Systolic Blood Pressure (SBP)')

# %%
# Practise 4
plt.scatter(df['HR'],df['SBP'])
plt.xlabel('Heart Rate (HR)')
plt.ylabel('Systolic Blood Pressure (SBP)')
plt.title("Week 4 Stuff")
#plt.show()
# Out:
# Text(0.5, 1.0, 'Week 4 Stuff')

# %%
plt.scatter(df['SBP'], df['DBP'], c=df['DBP'], cmap='hot')
plt.xlabel('Diastolic Blood Pressure (DBP)')
plt.ylabel('Systolic Blood Pressure (SBP)')
# Out:
# Text(0, 0.5, 'Systolic Blood Pressure (SBP)')

# %%
plt.scatter(df['HR'],df['SBP'], c=df['DBP'], s=40, cmap='afmhot')
#plt.scatter(df['SBP'],df['DBP'], c=df['HR'])
plt.xlabel('Heart Rate (HR)')
plt.ylabel('Systolic Blood Pressure (SBP)')
plt.show()

# %% [markdown]
# ### Substituting Values

# %%
df
# Out:
#      ID Gender       Visit     HR    SBP    DBP   DX AE
# 0   001      M  11/11/1998   88.0  140.0   80.0    1  0
# 1   016      F  11/13/1998   84.0  120.0   78.0    X  0
# 2   033      X  10/21/1998   68.0  190.0  100.0    3  1
# 3   004      F  01/01/1999  101.0  200.0  120.0    5  A
# 4   XX5      M  05/07/1998   68.0  120.0   80.0    1  0
# 5   006    NaN  06/15/1999   72.0  102.0   68.0    6  1
# 6   007      M  08/32/1998   88.0  148.0  102.0  NaN  0
# 7   008      F  08/08/1998  210.0    NaN    NaN    7  0
# 8   009      M  09/25/1999   86.0  240.0  180.0    4  1
# 9   010      F  10/19/1999   40.0  120.0    NaN    1  0
# 10  011      M  13/13/1998   68.0  300.0   20.0    4  1
# 11  012      M    10/12/98   60.0  122.0   74.0  NaN  0
# 12  013      2  08/23/1999   74.0  108.0   64.0  NaN  1
# 13  014      M  02/02/1999   22.0  130.0   90.0  NaN  1
# 14  002      f  11/13/1998   84.0  120.0   78.0    X  0
# 15  003      M  11/12/1999   58.0  112.0   74.0  NaN  0
# ...

# %%
filt = df['Gender'] == 'f' # Boolean

# %%
df['Gender'] = 'F'

# %%
df.loc[df['Gender'] == 'f', 'Gender'] = 'F'

# %%
df['Gender']

# %% [markdown]
# ### Removing Entries

# %%
df['SBP'].mean()
# Out:
# 143.55555555555554

# %%
df.groupby('Gender')['SBP'].mean()
# Out:
# Gender
# 2    108.000000
# F    140.769231
# M    149.636364
# X    190.000000
# Name: SBP, dtype: float64

# %%
# Practise 5
df.groupby('Gender')['SBP','DBP'].mean()
# Out:
# <ipython-input-66-c9486447b32b>:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df.groupby('Gender')['SBP','DBP'].mean()
#                SBP         DBP
# Gender
# 2       108.000000   64.000000
# F       140.769231   91.818182
# M       149.636364   83.636364
# X       190.000000  100.000000

# %%
df.shape
# Out:
# (30, 8)

# %%
df.groupby('Gender').mean()
# Out:
#                 HR         SBP         DBP
# Gender
# 2        74.000000  108.000000   64.000000
# F       151.153846  140.769231   91.818182
# M        64.833333  149.636364   83.636364
# X        68.000000  190.000000  100.000000

# %%
filt = df['SBP'] < 350

# %%
df
# Out:
#      ID Gender       Visit     HR    SBP    DBP   DX AE
# 0   001      M  11/11/1998   88.0  140.0   80.0    1  0
# 1   016      F  11/13/1998   84.0  120.0   78.0    X  0
# 2   033      X  10/21/1998   68.0  190.0  100.0    3  1
# 3   004      F  01/01/1999  101.0  200.0  120.0    5  A
# 4   XX5      M  05/07/1998   68.0  120.0   80.0    1  0
# 5   006    NaN  06/15/1999   72.0  102.0   68.0    6  1
# 6   007      M  08/32/1998   88.0  148.0  102.0  NaN  0
# 7   008      F  08/08/1998  210.0    NaN    NaN    7  0
# 8   009      M  09/25/1999   86.0  240.0  180.0    4  1
# 9   010      F  10/19/1999   40.0  120.0    NaN    1  0
# 10  011      M  13/13/1998   68.0  300.0   20.0    4  1
# 11  012      M    10/12/98   60.0  122.0   74.0  NaN  0
# 12  013      2  08/23/1999   74.0  108.0   64.0  NaN  1
# 13  014      M  02/02/1999   22.0  130.0   90.0  NaN  1
# 14  002      F  11/13/1998   84.0  120.0   78.0    X  2
# 15  003      M  11/12/1999   58.0  112.0   74.0  NaN  0
# ...

# %%
newDf = df[df['SBP'] <= 370]

# %%
newDf.shape
# Out:
# (26, 8)

# %%
newDf
# Out:
#      ID Gender       Visit     HR    SBP    DBP   DX AE
# 0   001      M  11/11/1998   88.0  140.0   80.0    1  0
# 1   016      F  11/13/1998   84.0  120.0   78.0    X  0
# 2   033      X  10/21/1998   68.0  190.0  100.0    3  1
# 3   004      F  01/01/1999  101.0  200.0  120.0    5  A
# 4   XX5      M  05/07/1998   68.0  120.0   80.0    1  0
# 5   006    NaN  06/15/1999   72.0  102.0   68.0    6  1
# 6   007      M  08/32/1998   88.0  148.0  102.0  NaN  0
# 8   009      M  09/25/1999   86.0  240.0  180.0    4  1
# 9   010      F  10/19/1999   40.0  120.0    NaN    1  0
# 10  011      M  13/13/1998   68.0  300.0   20.0    4  1
# 11  012      M    10/12/98   60.0  122.0   74.0  NaN  0
# 12  013      2  08/23/1999   74.0  108.0   64.0  NaN  1
# 13  014      M  02/02/1999   22.0  130.0   90.0  NaN  1
# 14  002      F  11/13/1998   84.0  120.0   78.0    X  2
# 15  003      M  11/12/1999   58.0  112.0   74.0  NaN  0
# 16  015      F         NaN   82.0  148.0   88.0    3  1
# ...

# %%
# Practise 6
filt2 = newDf['HR'] >= 27
df2 = newDf[filt2]
df2.shape
# Out:
# (22, 8)

# %%
df2
# Out:
#      ID Gender       Visit     HR    SBP    DBP   DX AE
# 0   001      M  11/11/1998   88.0  140.0   80.0    1  0
# 1   016      F  11/13/1998   84.0  120.0   78.0    X  0
# 2   033      X  10/21/1998   68.0  190.0  100.0    3  1
# 3   004      F  01/01/1999  101.0  200.0  120.0    5  A
# 4   XX5      M  05/07/1998   68.0  120.0   80.0    1  0
# 5   006    NaN  06/15/1999   72.0  102.0   68.0    6  1
# 6   007      M  08/32/1998   88.0  148.0  102.0  NaN  0
# 8   009      M  09/25/1999   86.0  240.0  180.0    4  1
# 9   010      F  10/19/1999   40.0  120.0    NaN    1  0
# 10  011      M  13/13/1998   68.0  300.0   20.0    4  1
# 11  012      M    10/12/98   60.0  122.0   74.0  NaN  0
# 12  013      2  08/23/1999   74.0  108.0   64.0  NaN  1
# 14  002      F  11/13/1998   84.0  120.0   78.0    X  2
# 15  003      M  11/12/1999   58.0  112.0   74.0  NaN  0
# 16  015      F         NaN   82.0  148.0   88.0    3  1
# 17  017      F  04/05/1999  208.0   84.0    NaN    2  0
# ...

# %%
# Practise 7
plt.scatter(df2['HR'],df2['SBP'], c=df2['DBP'])
plt.xlabel('Heart Rate (HR)')
plt.ylabel('Systolic Blood Pressure (SBP)')
plt.show()

# %% [markdown]
# *End of Laboratory*
